# %% [markdown]
# # Data Exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('archive/audio_features.csv').dropna().reset_index().drop('index', axis=1)
display(df.describe())
display(df.head())
# Out:
#        spotify_track_duration_ms  danceability        energy           key  \
# count               1.436500e+04  14365.000000  14365.000000  14365.000000
# mean                2.201395e+05      0.598544      0.617095      5.267943
# std                 6.924815e+04      0.154122      0.200270      3.547659
# min                 6.774900e+04      0.000000      0.000581      0.000000
# 25%                 1.741490e+05      0.497000      0.473000      2.000000
# 50%                 2.144000e+05      0.607000      0.632000      5.000000
# 75%                 2.529600e+05      0.708000      0.778000      8.000000
# max                 3.079157e+06      0.986000      0.997000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  14365.000000  14365.000000  14365.000000  14365.000000
# mean      -8.748437      0.730038      0.070305      0.299130
# std        3.570368      0.443955      0.078148      0.286728
# min      -28.030000      0.000000      0.000000      0.000006
# 25%      -11.076000      0.000000      0.031900      0.046000
# 50%       -8.318000      1.000000      0.040900      0.198000
# 75%       -5.987000      1.000000      0.066200      0.522000
# max        2.291000      1.000000      0.924000      0.990000
#
#        instrumentalness      liveness       valence         tempo  \
# count      14365.000000  14365.000000  14365.000000  14365.000000
# mean           0.036777      0.191837      0.606038    120.485874
# std            0.146994      0.159337      0.238596     27.825795
# min            0.000000      0.009670      0.000000      0.000000
# 25%            0.000000      0.090600      0.422000     99.432000
# 50%            0.000005      0.131000      0.627000    119.508000
# 75%            0.000587      0.248000      0.808000    136.610000
# max            0.982000      0.999000      0.991000    233.429000
#
#        time_signature  spotify_track_popularity
# count    14365.000000              14365.000000
# mean         3.928994                 39.690428
# std          0.321595                 22.714325
# min          0.000000                  0.000000
# 25%          4.000000                 20.000000
# 50%          4.000000                 41.000000
# 75%          4.000000                 58.000000
# max          5.000000                100.000000
#                                      song_id        performer  \
# 0     ......And Roses And RosesAndy Williams    Andy Williams
# 1        ...Baby One More TimeBritney Spears   Britney Spears
# 2                  '65 Love AffairPaul Davis       Paul Davis
# 3  'til I Can Make It On My OwnTammy Wynette    Tammy Wynette
# 4     'Til My Baby Comes HomeLuther Vandross  Luther Vandross
#
#                            song  \
# 0     ......And Roses And Roses
# 1         ...Baby One More Time
# 2               '65 Love Affair
# 3  'til I Can Make It On My Own
# 4       'Til My Baby Comes Home
#
#                                        spotify_genre        spotify_track_id  \
# 0  ['adult standards', 'brill building pop', 'eas...  3tvqPPpXyIgKrm4PR9HCf0
# 1              ['dance pop', 'pop', 'post-teen pop']  3MjUtNVVq3C8Fn0MP3zhXa
# 2  ['album rock', 'bubblegum pop', 'country rock'...  5nBp8F6tekSrnFg8G2Pvug
# 3     ['country', 'country dawn', 'nashville sound']  0aJHZYjwbfTmeyUWF7zGxI
# 4  ['funk', 'motown', 'neo soul', 'new jack swing...  2R97RZWUx4vAFbMMtmb5Ss
#
#                            spotify_track_preview_url  \
# 0  https://p.scdn.co/mp3-preview/cef4883cfd1e0e53...
# 1  https://p.scdn.co/mp3-preview/da2134a161f1cb34...
# 2  https://p.scdn.co/mp3-preview/a701445830ecacfb...
# 3  https://p.scdn.co/mp3-preview/73a24c43d2b48dc5...
# 4  https://p.scdn.co/mp3-preview/c54184ec2fc7e8bd...
#
#    spotify_track_duration_ms spotify_track_explicit  \
# 0                   166106.0                  False
# 1                   211066.0                  False
# 2                   219813.0                  False
# 3                   182080.0                  False
# 4                   332226.0                  False
#
#                               spotify_track_album  danceability  ...  \
# 0                     The Essential Andy Williams         0.154  ...
# 1  ...Baby One More Time (Digital Deluxe Version)         0.759  ...
# 2                          Radio Hits Of the '80s         0.647  ...
# 3                     The Essential Tammy Wynette         0.450  ...
# 4                        The Night I Fell In Love         0.804  ...
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   -14.063   1.0       0.0315        0.9110          0.000267    0.1120
# 1    -5.745   0.0       0.0307        0.2020          0.000131    0.4430
# 2    -4.247   0.0       0.0274        0.4320          0.000006    0.1330
# 3   -12.022   1.0       0.0318        0.8320          0.000035    0.1080
# 4    -6.714   0.0       0.1830        0.0567          0.000006    0.0253
#
#    valence    tempo  time_signature  spotify_track_popularity
# 0    0.150   83.969             4.0                      38.0
# 1    0.907   92.960             4.0                      77.0
# 2    0.952  155.697             4.0                      40.0
# 3    0.146  141.148             4.0                      31.0
# 4    0.802  139.663             4.0                      29.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Plotting

# %%
plt.scatter(df['danceability'], df['loudness'])

# %%
# sb.pairplot(df[10:])

# %%
plt.hist(df['danceability'], bins=50)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,   5.,   4.,  15.,  20.,  25.,  45.,
#          60.,  89., 120., 117., 152., 171., 188., 221., 246., 296., 345.,
#         424., 434., 515., 532., 608., 676., 633., 683., 718., 736., 720.,
#         714., 670., 620., 621., 552., 476., 394., 368., 263., 222., 203.,
#         162., 118.,  75.,  56.,  36.,  16.]),
#  array([0.     , 0.01972, 0.03944, 0.05916, 0.07888, 0.0986 , 0.11832,
#         0.13804, 0.15776, 0.17748, 0.1972 , 0.21692, 0.23664, 0.25636,
#         0.27608, 0.2958 , 0.31552, 0.33524, 0.35496, 0.37468, 0.3944 ,
#         0.41412, 0.43384, 0.45356, 0.47328, 0.493  , 0.51272, 0.53244,
#         0.55216, 0.57188, 0.5916 , 0.61132, 0.63104, 0.65076, 0.67048,
#         0.6902 , 0.70992, 0.72964, 0.74936, 0.76908, 0.7888 , 0.80852,
#         0.82824, 0.84796, 0.86768, 0.8874 , 0.90712, 0.92684, 0.94656,
#         0.96628, 0.986  ]),
#  <BarContainer object of 50 artists>)

# %%
df_s = df.sample(frac=0.3)
plt.xlabel('Loudness')
plt.ylabel('Energy')
plt.scatter(df_s['loudness'], df_s['energy'], s=0.5)

# %%
# display(df['danceability'].max())
df = df[df['danceability'] != 0]

plt.title("Danceability")
plt.boxplot(df['danceability'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f0bb6b4f3a0>,
#   <matplotlib.lines.Line2D at 0x7f0bb6b4f640>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f0bb6b4f8e0>,
#   <matplotlib.lines.Line2D at 0x7f0bb6b4fb80>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f0bb6b4f100>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f0bb6b4fe20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0bb6b5a100>],
#  'means': []}

# %%
import pyfpgrowth
from ast import literal_eval

sample = df['spotify_genre']
list = []

for s in df['spotify_genre']:
    list.append(literal_eval(s))

# sample = literal_eval(sample)
# sample
patterns = pyfpgrowth.find_frequent_patterns(list, 900)

# %%
most_popular = ['mellow gold',
                'soft rock',
                'adult standards',
                'dance pop',
                'pop',
                'brill building pop',
                'album rock',
                'rock',
                'classic rock',
                'pop rap',
                'soul',
                'motown',
                'bubblegum pop',
                'rap',
                'rock-and-roll',
                'quiet storm',
                'classic soul',
                'country',
                'r&b',
                'urban contemporary',
                'hip hop']

# %%
# for song in df:
# for i in len(df):
#     for genre in most_popular:
#         if genre in df.iloc[i]['spotify_genre']:
#             print
#             df.iloc[i]['spotify_genre'] = genre
#             break

# df['spotify_genre']

# %%
list = []

for i in range(len(df)):
    matched = False
    for genre in most_popular:
        if genre in df.iloc[i]['spotify_genre']:
            df.at[i, 'spotify_genre'] = [genre]
            matched = True
            break
    if(not matched):
        list.append(i)
    
df = df.drop(list)

# df = df[len(df['spotify_genre']) == 1]

# %%
df = df.drop(['song_id', 'performer', 'song', 'spotify_track_id', 'spotify_track_preview_url', 'spotify_track_album', 'mode'], axis=1)

# %% [markdown]
# ## Removing outliers

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# y = df['spotify_genre']
# X = df.drop('spotify_genre', axis=1).dropna()
# display(y)

# %%
df = df[df['spotify_track_duration_ms'] < 3_000_000]
df = df[df['danceability'] > 0.001]
df = df[df['energy'] > 0.03]
df = df[df['loudness'] < 0]
df = df[df['speechiness'] < 0.8]
df = df[df['tempo'] > 50]

# %%
df.describe()
# Out:
#        spotify_track_duration_ms  danceability        energy           key  \
# count               1.217900e+04  12179.000000  12179.000000  12179.000000
# mean                2.202439e+05      0.599559      0.618252      5.268002
# std                 6.510559e+04      0.154814      0.198880      3.549283
# min                 6.774900e+04      0.103000      0.031600      0.000000
# 25%                 1.748130e+05      0.497000      0.475000      2.000000
# 50%                 2.146170e+05      0.608000      0.634000      5.000000
# 75%                 2.528130e+05      0.710000      0.778000      8.000000
# max                 1.367093e+06      0.986000      0.997000     11.000000
#
#            loudness   speechiness  acousticness  instrumentalness  \
# count  12179.000000  12179.000000  12179.000000      12179.000000
# mean      -8.714147      0.070373      0.296446          0.035741
# std        3.542551      0.076735      0.285015          0.144451
# min      -28.030000      0.022100      0.000008          0.000000
# 25%      -11.058000      0.032000      0.045250          0.000000
# 50%       -8.285000      0.040900      0.197000          0.000005
# 75%       -5.964000      0.066200      0.516500          0.000550
# max       -0.463000      0.693000      0.989000          0.982000
#
#            liveness       valence         tempo  time_signature  \
# count  12179.000000  12179.000000  12179.000000    12179.000000
# mean       0.192197      0.605472    120.502685        3.931275
# std        0.159328      0.238308     27.621783        0.313316
# min        0.009670      0.034900     58.382000        1.000000
# 25%        0.090900      0.421000     99.823500        4.000000
# 50%        0.132000      0.626000    119.567000        4.000000
# 75%        0.249000      0.806000    136.464000        4.000000
# max        0.997000      0.991000    233.429000        5.000000
#
#        spotify_track_popularity
# count              12179.000000
# mean                  39.887101
# std                   22.789489
# min                    0.000000
# 25%                   21.000000
# 50%                   41.000000
# 75%                   58.000000
# max                  100.000000

# %%
mms = MinMaxScaler()

# df['spotify_track_duration_ms'] = mms.fit_transform(df['spotify_track_duration_ms'])
# df['loudness'] = mms.fit_transform(df['loudness'])
# df['tempo'] = mms.fit_transform(df['tempo'])
# df['spotify_track_popularity'] = mms.fit_transform(df['spotify_track_popularity'])

df[['spotify_track_duration_ms','loudness','tempo','spotify_track_popularity']] = mms.fit_transform(df[['spotify_track_duration_ms','loudness', 'tempo', 'spotify_track_popularity']])

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MultiLabelBinarizer

# Assuming df['spotify_genre'] is a list of strings
mlb = MultiLabelBinarizer()
y = mlb.fit_transform(df['spotify_genre'])
X = df.drop(['spotify_genre', 'spotify_track_explicit', 'time_signature', 'key'], axis=1).dropna()

knn = KNeighborsClassifier(n_neighbors=1, metric="euclidean")

selector = SequentialFeatureSelector(knn, n_features_to_select=5 ,direction="forward")

selector.fit(X, y)

selected_features = selector.get_support()

for i in range(len(selected_features)):
    if selected_features[i]:
        print(X.columns[i])

X_t = selector.transform(X)
# Out:
#        spotify_track_duration_ms  danceability  energy  loudness  speechiness  \
# 0                       0.075697         0.154   0.185  0.506657       0.0315
# 1                       0.110300         0.759   0.699  0.808394       0.0307
# 2                       0.117031         0.647   0.686  0.862734       0.0274
# 3                       0.087991         0.450   0.294  0.580694       0.0318
# 4                       0.203547         0.804   0.714  0.773243       0.1830
# ...                          ...           ...     ...       ...          ...
# 14358                   0.123916         0.861   0.603  0.806834       0.1760
# 14359                   0.103855         0.667   0.851  0.826096       0.0629
# 14361                   0.143962         0.448   0.826  0.899119       0.0319
# 14362                   0.162143         0.852   0.438  0.738455       0.4260
# 14364                   0.157965         0.846   0.657  0.667029       0.1400
#
#        acousticness  instrumentalness  liveness  valence     tempo  \
# 0           0.91100          0.000267    0.1120    0.150  0.146172
# 1           0.20200          0.000131    0.4430    0.907  0.197536
# 2           0.43200          0.000006    0.1330    0.952  0.555936
# 3           0.83200          0.000035    0.1080    0.146  0.472822
# 4           0.05670          0.000006    0.0253    0.802  0.464338
# ...             ...               ...       ...      ...       ...
# 14358       0.05210          0.000000    0.0924    0.504  0.226573
# 14359       0.03380          0.000001    0.3180    0.830  0.352762
# 14361       0.00756          0.000000    0.1170    0.190  0.106891
# 14362       0.01450          0.000000    0.2630    0.627  0.528789
# 14364       0.04780          0.000363    0.0392    0.619  0.259136
#
#        spotify_track_popularity
# 0                          0.38
# 1                          0.77
# 2                          0.40
# 3                          0.31
# 4                          0.29
# ...                         ...
# 14358                      0.84
# 14359                      0.32
# 14361                      0.74
# 14362                      0.51
# 14364                      0.28
#
# [12179 rows x 11 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/owadestig/plugg/dm/DataMining/Project/Exploration.ipynb Cell 22 in <cell line: 13>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/owadestig/plugg/dm/DataMining/Project/Exploration.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> selector=SequentialFeatureSelector(knn, n_features_to_select=5 ,direction="forward")
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/owadestig/plugg/dm/DataMining/Project/Exploration.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> display(X)
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/owadestig/plugg/dm/DataMining/Project/Exploration.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> selector.fit(X, y)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/owadestig/plugg/dm/DataMining/Project/Exploration.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> list = selector.get_support()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/owadestig/plugg/dm/DataMining/Project/Exploration.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> for i in range(len(list)):
#
# File ~/.local/lib/python3.8/site-packages/sklearn/feature_selection/_sequential.py:209, in SequentialFeatureSelector.fit(self, X, y)
#     203 n_iterations = (
#     204     self.n_features_to_select_
#     205     if self.direction == "forward"
#     206     else n_features - self.n_features_to_select_
#     207 )
#     208 for _ in range(n_iterations):
# --> 209     new_feature_idx = self._get_best_new_feature(
#     210         cloned_estimator, X, y, current_mask
#     211     )
#     212     current_mask[new_feature_idx] = True
#     214 if self.direction == "backward":
#
# File ~/.local/lib/python3.8/site-packages/sklearn/feature_selection/_sequential.py:232, in SequentialFeatureSelector._get_best_new_feature(self, estimator, X, y, current_mask)
#     230         candidate_mask = ~candidate_mask
#     231     X_new = X[:, candidate_mask]
# --> 232     scores[feature_idx] = cross_val_score(
#     233         estimator,
#     234         X_new,
#     235         y,
#     236         cv=self.cv,
#     237         scoring=self.scoring,
#     238         n_jobs=self.n_jobs,
#     239     ).mean()
#     240 return max(scores, key=lambda feature_idx: scores[feature_idx])
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:509, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     506 # To ensure multimetric format is not supported
#     507 scorer = check_scoring(estimator, scoring=scoring)
# --> 509 cv_results = cross_validate(
#     510     estimator=estimator,
#     511     X=X,
#     512     y=y,
#     513     groups=groups,
#     514     scoring={"score": scorer},
#     515     cv=cv,
#     516     n_jobs=n_jobs,
#     517     verbose=verbose,
#     518     fit_params=fit_params,
#     519     pre_dispatch=pre_dispatch,
#     520     error_score=error_score,
#     521 )
#     522 return cv_results["test_score"]
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:255, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#      64 """Evaluate metric(s) by cross-validation and also record fit/score times.
#      65
#      66 Read more in the :ref:`User Guide <multimetric_cross_validation>`.
#    (...)
#     251
#     252 """
#     253 X, y, groups = indexable(X, y, groups)
# --> 255 cv = check_cv(cv, y, classifier=is_classifier(estimator))
#     257 if callable(scoring):
#     258     scorers = scoring
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:2303, in check_cv(cv, y, classifier)
#    2298 cv = 5 if cv is None else cv
#    2299 if isinstance(cv, numbers.Integral):
#    2300     if (
#    2301         classifier
#    2302         and (y is not None)
# -> 2303         and (type_of_target(y) in ("binary", "multiclass"))
#    2304     ):
#    2305         return StratifiedKFold(cv)
#    2306     else:
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/multiclass.py:299, in type_of_target(y)
#     293 try:
#     294     if (
#     295         not hasattr(y[0], "__array__")
#     296         and isinstance(y[0], Sequence)
#     297         and not isinstance(y[0], str)
#     298     ):
# --> 299         raise ValueError(
#     300             "You appear to be using a legacy multi-label data"
#     301             " representation. Sequence of sequences are no"
#     302             " longer supported; use a binary array or sparse"
#     303             " matrix instead - the MultiLabelBinarizer"
#     304             " transformer can convert to this format."
#     305         )
#     306 except IndexError:
#     307     pass
#
# ValueError: You appear to be using a legacy multi-label data representation. Sequence of sequences are no longer supported; use a binary array or sparse matrix instead - the MultiLabelBinarizer transformer can convert to this format.
